# %%
import pandas as pd
import numpy as np
from datetime import date, datetime, timedelta
import calendar

# %%
data_df = pd.read_csv("..\project 4\Police_Department_Incident_Reports__2018_to_Present (1).csv")

# %%
filtered_data_df = data_df.filter(['Incident Datetime', 'Incident Day of Week', 'Incident Subcategory', 'Analysis Neighborhood', 'Intersection', 'Latitude', 'Longitude'], axis=1)
filtered_data_df['Incident Subcategory']=filtered_data_df['Incident Subcategory'].fillna('No cathegory')
filtered_data_df=filtered_data_df[filtered_data_df['Incident Subcategory'].str.contains("Vehicle")]

# %%
filtered_data_df['Incident Datetime'] = pd.to_datetime(filtered_data_df['Incident Datetime'])

# %%
filtered_data_df['Incident hour'] = filtered_data_df['Incident Datetime'].apply(lambda x: x.hour)

# %%
filtered_data_df['Incident month'] = filtered_data_df['Incident Datetime'].apply(lambda x: x.month)

# %%
filtered_data_df['Incident Date'] = filtered_data_df['Incident Datetime'].dt.date

# %%
filtered_data_df=filtered_data_df.drop('Incident Datetime', axis =1)

# %%
hour_range_map = {
  0: "0-3",
  1: "4-7",
  2: "8-11",
  3: "12-15",
  4: "16-19",
  5: "20-23", 
}

# %%
filtered_data_df['hour_range'] = filtered_data_df['Incident hour'].apply(lambda x:hour_range_map[(int)(x/4)])

# %%
filtered_data_df.head()
# Out:
#   Incident Day of Week    Incident Subcategory Analysis Neighborhood  \
# 0               Monday       Recovered Vehicle                   NaN
# 2               Monday       Recovered Vehicle                   NaN
# 3               Monday       Recovered Vehicle                   NaN
# 4              Tuesday       Recovered Vehicle                   NaN
# 6             Saturday  Larceny - From Vehicle                   NaN
#
#   Intersection  Latitude  Longitude  Incident hour  Incident month  \
# 0          NaN       NaN        NaN             23               3
# 2          NaN       NaN        NaN             13               3
# 3          NaN       NaN        NaN             10               3
# 4          NaN       NaN        NaN             18               3
# 6          NaN       NaN        NaN             12               3
#
#   Incident Date hour_range
# 0    2023-03-13      20-23
# 2    2023-03-13      12-15
# 3    2023-03-13       8-11
# 4    2023-03-14      16-19
# 6    2023-03-11      12-15

# %%
positive_df = filtered_data_df.filter(['Incident Date', 'Incident Day of Week', 'hour_range' , 'Analysis Neighborhood'], axis=1)

# %%
positive_df=positive_df.dropna()
positive_df['Incident occured'] =1
positive_df.head()
# Out:
#      Incident Date Incident Day of Week hour_range Analysis Neighborhood  \
# 731     2021-09-06               Monday        4-7          Potrero Hill
# 820     2021-10-21             Thursday      12-15               Portola
# 1170    2022-01-24               Monday      16-19              Nob Hill
# 1683    2022-01-17               Monday       8-11              Nob Hill
# 1749    2021-10-11               Monday      12-15              Nob Hill
#
#       Incident occured
# 731                  1
# 820                  1
# 1170                 1
# 1683                 1
# 1749                 1

# %%
positive_df.shape
# Out:
# (187468, 5)

# %%
len(positive_df['Analysis Neighborhood'].unique())
# Out:
# 41

# %%
from datetime import date, datetime, timedelta

def datespan(startDate, endDate, delta=timedelta(days=1)):
    currentDate = startDate
    while currentDate < endDate:
        yield currentDate
        currentDate += delta

# %%
hour_range = []
date =[]
day=[]

for timestamp in datespan(datetime(2018, 1, 1, 0, 0), 
                          datetime(2020, 10, 27, 1, 0), 
                          delta=timedelta(hours=4)):
    x= hour_range_map[(int)((timestamp.hour)/4)]
    hour_range.append(x)
    date.append(timestamp.date())
    day.append(calendar.day_name[timestamp.date().weekday()])
#     print (x , timestamp.date(),calendar.day_name[timestamp.date().weekday()])
    
negative_df = pd.DataFrame({'Incident Date': date,'Incident Day of Week':day,'hour_range':hour_range})

# %%
negative_df['Incident occured'] =0
negative_df.head(20)
# Out:
#    Incident Date Incident Day of Week hour_range  Incident occured
# 0     2018-01-01               Monday        0-3                 0
# 1     2018-01-01               Monday        4-7                 0
# 2     2018-01-01               Monday       8-11                 0
# 3     2018-01-01               Monday      12-15                 0
# 4     2018-01-01               Monday      16-19                 0
# 5     2018-01-01               Monday      20-23                 0
# 6     2018-01-02              Tuesday        0-3                 0
# 7     2018-01-02              Tuesday        4-7                 0
# 8     2018-01-02              Tuesday       8-11                 0
# 9     2018-01-02              Tuesday      12-15                 0
# 10    2018-01-02              Tuesday      16-19                 0
# 11    2018-01-02              Tuesday      20-23                 0
# 12    2018-01-03            Wednesday        0-3                 0
# 13    2018-01-03            Wednesday        4-7                 0
# 14    2018-01-03            Wednesday       8-11                 0
# 15    2018-01-03            Wednesday      12-15                 0
# 16    2018-01-03            Wednesday      16-19                 0
# 17    2018-01-03            Wednesday      20-23                 0
# 18    2018-01-04             Thursday        0-3                 0
# 19    2018-01-04             Thursday        4-7                 0

# %%
neighborhood_list = positive_df['Analysis Neighborhood'].unique().tolist()

# %%
negative_data = pd.DataFrame()
for neighborhood in neighborhood_list:
    negative_df['Analysis Neighborhood'] = neighborhood
    negative_data = pd.concat([negative_data,negative_df])

# %%
on = ['Incident Date', 'Incident Day of Week', 'hour_range', 'Analysis Neighborhood']

negative_data = (negative_data.merge(positive_df[on], on=on, how='left', indicator=True)
              .query('_merge == "left_only"').drop('_merge', 1))
# Out:
# C:\Users\lulum\AppData\Local\Temp\ipykernel_14884\329048794.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   negative_data = (negative_data.merge(positive_df[on], on=on, how='left', indicator=True)

# %%
positive_df.shape
# Out:
# (187468, 5)

# %%
negative_data.shape
# Out:
# (191760, 5)

# %%
data = pd.concat([positive_df,negative_data])

# %%
data = data.sort_values(['Incident Date', 'Analysis Neighborhood','hour_range'])
data.head(5)
# Out:
#        Incident Date Incident Day of Week hour_range  Analysis Neighborhood  \
# 356772    2018-01-01               Monday        0-3  Bayview Hunters Point
# 296539    2018-01-01               Monday      12-15  Bayview Hunters Point
# 384431    2018-01-01               Monday      12-15  Bayview Hunters Point
# 533635    2018-01-01               Monday      12-15  Bayview Hunters Point
# 54870     2018-01-01               Monday      16-19  Bayview Hunters Point
#
#         Incident occured
# 356772                 1
# 296539                 1
# 384431                 1
# 533635                 1
# 54870                  0

# %%
data=data.drop('Incident Date', axis =1)

# %%
len(data.columns)
# Out:
# 4

# %%
data['Incident occured'] = data['Incident occured'].astype('category')

# %%
data = pd.concat([data,pd.get_dummies(data[['Incident Day of Week', 'hour_range', 'Analysis Neighborhood']], sparse=True)],axis=1)

# %%
data.drop(['Incident Day of Week', 'hour_range', 'Analysis Neighborhood'],axis=1,inplace=True)

# %%
label = data.pop('Incident occured')

# %%
data['Incident occured'] = label

# %%
data.head()
# Out:
#         Incident Day of Week_Friday  Incident Day of Week_Monday  \
# 356772                            0                            1
# 296539                            0                            1
# 384431                            0                            1
# 533635                            0                            1
# 54870                             0                            1
#
#         Incident Day of Week_Saturday  Incident Day of Week_Sunday  \
# 356772                              0                            0
# 296539                              0                            0
# 384431                              0                            0
# 533635                              0                            0
# 54870                               0                            0
#
#         Incident Day of Week_Thursday  Incident Day of Week_Tuesday  \
# 356772                              0                             0
# 296539                              0                             0
# 384431                              0                             0
# 533635                              0                             0
# 54870                               0                             0
#
#         Incident Day of Week_Wednesday  hour_range_0-3  hour_range_12-15  \
# 356772                               0               1                 0
# 296539                               0               0                 1
# 384431                               0               0                 1
# 533635                               0               0                 1
# 54870                                0               0                 0
#
#         hour_range_16-19  ...  Analysis Neighborhood_Seacliff  \
# 356772                 0  ...                               0
# 296539                 0  ...                               0
# 384431                 0  ...                               0
# 533635                 0  ...                               0
# 54870                  1  ...                               0
#
#         Analysis Neighborhood_South of Market  \
# 356772                                      0
# 296539                                      0
# 384431                                      0
# 533635                                      0
# 54870                                       0
#
#         Analysis Neighborhood_Sunset/Parkside  \
# 356772                                      0
# 296539                                      0
# 384431                                      0
# 533635                                      0
# 54870                                       0
#
#         Analysis Neighborhood_Tenderloin  \
# 356772                                 0
# 296539                                 0
# 384431                                 0
# 533635                                 0
# 54870                                  0
#
#         Analysis Neighborhood_Treasure Island  \
# 356772                                      0
# 296539                                      0
# 384431                                      0
# 533635                                      0
# 54870                                       0
#
#         Analysis Neighborhood_Twin Peaks  \
# 356772                                 0
# 296539                                 0
# 384431                                 0
# 533635                                 0
# 54870                                  0
#
#         Analysis Neighborhood_Visitacion Valley  \
# 356772                                        0
# 296539                                        0
# 384431                                        0
# 533635                                        0
# 54870                                         0
#
#         Analysis Neighborhood_West of Twin Peaks  \
# 356772                                         0
# 296539                                         0
# 384431                                         0
# 533635                                         0
# 54870                                          0
#
#         Analysis Neighborhood_Western Addition  Incident occured
# 356772                                       0                 1
# 296539                                       0                 1
# 384431                                       0                 1
# 533635                                       0                 1
# 54870                                        0                 0
#
# [5 rows x 55 columns]

# %%
data.dtypes
# Out:
# Incident Day of Week_Friday                             Sparse[uint8, 0]
# Incident Day of Week_Monday                             Sparse[uint8, 0]
# Incident Day of Week_Saturday                           Sparse[uint8, 0]
# Incident Day of Week_Sunday                             Sparse[uint8, 0]
# Incident Day of Week_Thursday                           Sparse[uint8, 0]
# Incident Day of Week_Tuesday                            Sparse[uint8, 0]
# Incident Day of Week_Wednesday                          Sparse[uint8, 0]
# hour_range_0-3                                          Sparse[uint8, 0]
# hour_range_12-15                                        Sparse[uint8, 0]
# hour_range_16-19                                        Sparse[uint8, 0]
# hour_range_20-23                                        Sparse[uint8, 0]
# hour_range_4-7                                          Sparse[uint8, 0]
# hour_range_8-11                                         Sparse[uint8, 0]
# Analysis Neighborhood_Bayview Hunters Point             Sparse[uint8, 0]
# Analysis Neighborhood_Bernal Heights                    Sparse[uint8, 0]
# Analysis Neighborhood_Castro/Upper Market               Sparse[uint8, 0]
# Analysis Neighborhood_Chinatown                         Sparse[uint8, 0]
# Analysis Neighborhood_Excelsior                         Sparse[uint8, 0]
# Analysis Neighborhood_Financial District/South Beach    Sparse[uint8, 0]
# Analysis Neighborhood_Glen Park                         Sparse[uint8, 0]
# Analysis Neighborhood_Golden Gate Park                  Sparse[uint8, 0]
# Analysis Neighborhood_Haight Ashbury                    Sparse[uint8, 0]
# Analysis Neighborhood_Hayes Valley                      Sparse[uint8, 0]
# Analysis Neighborhood_Inner Richmond                    Sparse[uint8, 0]
# Analysis Neighborhood_Inner Sunset                      Sparse[uint8, 0]
# Analysis Neighborhood_Japantown                         Sparse[uint8, 0]
# Analysis Neighborhood_Lakeshore                         Sparse[uint8, 0]
# Analysis Neighborhood_Lincoln Park                      Sparse[uint8, 0]
# Analysis Neighborhood_Lone Mountain/USF                 Sparse[uint8, 0]
# Analysis Neighborhood_Marina                            Sparse[uint8, 0]
# Analysis Neighborhood_McLaren Park                      Sparse[uint8, 0]
# Analysis Neighborhood_Mission                           Sparse[uint8, 0]
# Analysis Neighborhood_Mission Bay                       Sparse[uint8, 0]
# Analysis Neighborhood_Nob Hill                          Sparse[uint8, 0]
# Analysis Neighborhood_Noe Valley                        Sparse[uint8, 0]
# Analysis Neighborhood_North Beach                       Sparse[uint8, 0]
# Analysis Neighborhood_Oceanview/Merced/Ingleside        Sparse[uint8, 0]
# Analysis Neighborhood_Outer Mission                     Sparse[uint8, 0]
# Analysis Neighborhood_Outer Richmond                    Sparse[uint8, 0]
# Analysis Neighborhood_Pacific Heights                   Sparse[uint8, 0]
# Analysis Neighborhood_Portola                           Sparse[uint8, 0]
# Analysis Neighborhood_Potrero Hill                      Sparse[uint8, 0]
# Analysis Neighborhood_Presidio                          Sparse[uint8, 0]
# Analysis Neighborhood_Presidio Heights                  Sparse[uint8, 0]
# Analysis Neighborhood_Russian Hill                      Sparse[uint8, 0]
# Analysis Neighborhood_Seacliff                          Sparse[uint8, 0]
# Analysis Neighborhood_South of Market                   Sparse[uint8, 0]
# Analysis Neighborhood_Sunset/Parkside                   Sparse[uint8, 0]
# Analysis Neighborhood_Tenderloin                        Sparse[uint8, 0]
# Analysis Neighborhood_Treasure Island                   Sparse[uint8, 0]
# Analysis Neighborhood_Twin Peaks                        Sparse[uint8, 0]
# Analysis Neighborhood_Visitacion Valley                 Sparse[uint8, 0]
# Analysis Neighborhood_West of Twin Peaks                Sparse[uint8, 0]
# Analysis Neighborhood_Western Addition                  Sparse[uint8, 0]
# Incident occured                                                category
# dtype: object

# %%
data['Incident occured'].hist()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt

# %%
data= data.sample(frac=1)
X = data.iloc[:,:-1]
y = data.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
X_train
# Out:
#         Incident Day of Week_Friday  Incident Day of Week_Monday  \
# 271240                            0                            1
# 159841                            0                            0
# 13975                             0                            0
# 58792                             1                            0
# 254709                            0                            0
# ...                             ...                          ...
# 31690                             0                            0
# 64799                             0                            1
# 92275                             0                            1
# 81115                             0                            0
# 55980                             0                            0
#
#         Incident Day of Week_Saturday  Incident Day of Week_Sunday  \
# 271240                              0                            0
# 159841                              0                            1
# 13975                               1                            0
# 58792                               0                            0
# 254709                              0                            0
# ...                               ...                          ...
# 31690                               1                            0
# 64799                               0                            0
# 92275                               0                            0
# 81115                               1                            0
# 55980                               1                            0
#
#         Incident Day of Week_Thursday  Incident Day of Week_Tuesday  \
# 271240                              0                             0
# 159841                              0                             0
# 13975                               0                             0
# 58792                               0                             0
# 254709                              1                             0
# ...                               ...                           ...
# 31690                               0                             0
# 64799                               0                             0
# 92275                               0                             0
# 81115                               0                             0
# 55980                               0                             0
#
#         Incident Day of Week_Wednesday  hour_range_0-3  hour_range_12-15  \
# 271240                               0               0                 1
# 159841                               0               0                 1
# 13975                                0               0                 1
# 58792                                0               0                 0
# 254709                               0               0                 0
# ...                                ...             ...               ...
# 31690                                0               0                 0
# 64799                                0               1                 0
# 92275                                0               0                 0
# 81115                                0               0                 0
# 55980                                0               0                 1
#
#         hour_range_16-19  ...  Analysis Neighborhood_Russian Hill  \
# 271240                 0  ...                                   0
# 159841                 0  ...                                   0
# 13975                  0  ...                                   0
# 58792                  1  ...                                   0
# 254709                 0  ...                                   0
# ...                  ...  ...                                 ...
# 31690                  0  ...                                   0
# 64799                  0  ...                                   0
# 92275                  0  ...                                   0
# 81115                  0  ...                                   0
# 55980                  0  ...                                   0
#
#         Analysis Neighborhood_Seacliff  Analysis Neighborhood_South of Market  \
# 271240                               0                                      0
# 159841                               0                                      0
# 13975                                0                                      0
# 58792                                0                                      0
# 254709                               0                                      0
# ...                                ...                                    ...
# 31690                                0                                      0
# 64799                                0                                      0
# 92275                                0                                      0
# 81115                                0                                      0
# 55980                                0                                      0
#
#         Analysis Neighborhood_Sunset/Parkside  \
# 271240                                      0
# 159841                                      0
# 13975                                       0
# 58792                                       0
# 254709                                      0
# ...                                       ...
# 31690                                       0
# 64799                                       0
# 92275                                       0
# 81115                                       1
# 55980                                       0
#
#         Analysis Neighborhood_Tenderloin  \
# 271240                                 0
# 159841                                 0
# 13975                                  0
# 58792                                  0
# 254709                                 0
# ...                                  ...
# 31690                                  0
# 64799                                  0
# 92275                                  0
# 81115                                  0
# 55980                                  0
#
#         Analysis Neighborhood_Treasure Island  \
# 271240                                      0
# 159841                                      0
# 13975                                       0
# 58792                                       0
# 254709                                      1
# ...                                       ...
# 31690                                       0
# 64799                                       0
# 92275                                       0
# 81115                                       0
# 55980                                       0
#
#         Analysis Neighborhood_Twin Peaks  \
# 271240                                 0
# 159841                                 0
# 13975                                  0
# 58792                                  0
# 254709                                 0
# ...                                  ...
# 31690                                  0
# 64799                                  0
# 92275                                  0
# 81115                                  0
# 55980                                  0
#
#         Analysis Neighborhood_Visitacion Valley  \
# 271240                                        0
# 159841                                        0
# 13975                                         0
# 58792                                         0
# 254709                                        0
# ...                                         ...
# 31690                                         0
# 64799                                         0
# 92275                                         0
# 81115                                         0
# 55980                                         0
#
#         Analysis Neighborhood_West of Twin Peaks  \
# 271240                                         0
# 159841                                         0
# 13975                                          0
# 58792                                          0
# 254709                                         0
# ...                                          ...
# 31690                                          0
# 64799                                          0
# 92275                                          0
# 81115                                          0
# 55980                                          0
#
#         Analysis Neighborhood_Western Addition
# 271240                                       0
# 159841                                       0
# 13975                                        0
# 58792                                        0
# 254709                                       0
# ...                                        ...
# 31690                                        0
# 64799                                        0
# 92275                                        0
# 81115                                        0
# 55980                                        0
#
# [265459 rows x 54 columns]

# %%
logistic_regression= LogisticRegression()
logistic_regression.fit(X_train,y_train)
y_pred=logistic_regression.predict(X_test)

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True)
# Out:
# <Axes: xlabel='Predicted', ylabel='Actual'>

# %%
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
plt.show()
# Out:
# Accuracy:  0.7244943701711363

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True)
# Out:
# <Axes: xlabel='Predicted', ylabel='Actual'>

# %%
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
plt.show()
# Out:
# Accuracy:  0.7337499670384727
